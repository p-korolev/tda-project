# %% [markdown]
# # TDA Testing: Graph Structure Differences Between Correlated & Uncorrelated Equity Prices
#
# ### Overview and Motivation
# We know that equities who share numerous similar characteristics like sector and company products/services move closely in regards to stock performance. One of the more common ways to get a formal sense this comovement might be to measure the correlation between the prices on some period $[t_i, t_{i+l}]$. Similarly, we can visualize state patterns between the two series of prices by building a scatter plot where each point $p_i$ represents the price of two or more equities at time $t_i$:
#
# $$
# p_i = (P_{E_1}(t_i), P_{E_2}(t_i))
# $$
#
# A scatter plot like this allows us to guess the correlation pretty accurately, and gives us an immediate (but rough) idea of whether or not the prices of the equities do in fact move together.
#
# In this notebook, we will use Topological Data Analysis (TDA) to uncover some structure similarities between Mapper graphs generated by highly correlated series of price data. Likewise, we will generate graphs for uncorrelated series of price data to observe graph structures of this case. Ultimately, we should be able to build an intuition to differentiate whether or not our data was highly correlated to begin with given resulting graphs.
#
# ### Mapper Algorithm
# The Mapper algorithm uses a filteration process to project our data $X \subset \mathbb{R}^d$ onto a smaller dimension $\mathbb{R^k}, k < d$. In $\mathbb{R}^k$, we create overlapping covers to split and group the image points in the filtered space into these covers. After reclassifying our original pre-image points in $\mathbb{R}^d$ with their respective cover, we apply a clustering method onto each cover of points. This clustering step allows us to then construct a graph where each node represents a cluster, and each edge is present if and only if there exists overlapping points between clusters.
#
# In this notebook, we will use the following methodology:
#
# 1. Normalize Data $X \subset \mathbb{R}^2$.
# 2. Choose lens (filtration) function $f: X \to \mathbb{R}$ and apply to our data.
# 3. Create overlapping intervals (covers) $I_1, I_2, ..., I_N$ such that:
#
# $$
# [\min f(X), \max f(X)] = \bigcup_{i=1}^N I_i.
# $$
#
# 4. Classify points $f(X)$ by cover.
# 5. Cluster each group of points $f^{-1}(X) \in \mathbb{R}^d$ where $f(X)$ belongs to the group.
# 6. Construct graph where each node $N_i$ represents the cluster $C_i$, and an edge connects $N_i, N_j$ if and only if there exists a point $x \in X$ such that $x \in C_i \cap C_j$.
#
# ### Fetching Correlated Data Sets
# In this section, we will look to construct and normalize price-price datasets $X_1, X_2, ..., X_5$ where the correlation between between its two involved series of price data is highly correlated. As a cutoff bias, we aim to achieve a correlation coefficient of $\rho > 0.85$.
#
# To start, let us look within the Energy sector of the U.S. market and pull a handful of the largest equities within this sector. Then, using a time period of one year, we will check and rank the correlation between these stocks' performance.

# %%
import yfinance as yf
import pandas as pd
import numpy as np

# Sector-leading equities:
eqs = ["XOM", "CVX", "COP", "WMB", "EPD", "KMI", "EOG", "MPC", "MPLX", "VLO", "PSX", "SLB", "BKR"]
price_series = []
for e in eqs:
    data = yf.Ticker(e).history(start="2024-01-01", end="2025-11-22", interval='1d')["Close"]
    price_series.append(data.rename(e))

price_df = pd.concat(price_series, axis=1)
corr_matrix = price_df.corr()
#print(corr_matrix)

threshold = 0.85

# upper-triangle mask (excluding diagonal)
mask = np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)

# apply mask + threshold
rows, cols = np.where((corr_matrix.values > threshold) & mask)

for i, j in zip(rows, cols):
    print(f"({corr_matrix.index[i]}, {corr_matrix.columns[j]}): {corr_matrix.iat[i, j]:.3f}")
# Out:
# (COP, SLB): 0.894
# (WMB, EPD): 0.937
# (WMB, KMI): 0.986
# (WMB, MPLX): 0.960
# (WMB, BKR): 0.876
# (EPD, KMI): 0.944
# (EPD, MPLX): 0.975
# (EPD, BKR): 0.903
# (KMI, MPLX): 0.951
# (KMI, BKR): 0.867
# (MPC, VLO): 0.942
# (MPLX, BKR): 0.877

# %% [markdown]
# Above, we can select the following equity pairs to build our datasets with:
#
# * $X_1 = [\text{WMB } \text{KMI}]$
# * $X_2 = [\text{EPD } \text{MPLX}]$
# * $X_3 = [\text{WMB } \text{MPLX}]$
# * $X_4 = [\text{KMI } \text{MPLX}]$
# * $X_2 = [\text{MPC } \text{VLO}]$
#
# And out of curiosity, we can generate a scatter plot for $X_1$:

# %%
import matplotlib.pyplot as plt

plt.scatter(x=price_df['WMB'], y=price_df['KMI'], s=8)
plt.xlabel("WMB Price")
plt.ylabel("KMI Price")
plt.tight_layout()
plt.show()

# %% [markdown]
# Now that we know what data we are going to work with going forward in this section, we will build $X_1, .., X_5 \subset \mathbb{R}^2$ and normalize values using a Z-score. For a value $x$ in some data:
#
# $$
# x_{normalized} = \frac{x - \mu}{\sigma}
# $$

# %%
from sklearn.preprocessing import StandardScaler

# Build X_1 with raw prices
X1_raw = np.column_stack([price_df["WMB"], price_df["KMI"]])
print("X1_raw.head:\n", X1_raw[:5])

# Normalize X_1 raw
X1 = StandardScaler().fit_transform(X1_raw)
print("X1.head:\n", X1[:5])

# Repeat for other datasets
X2 = StandardScaler().fit_transform(np.column_stack([price_df["EPD"], price_df["MPLX"]]))
X3 = StandardScaler().fit_transform(np.column_stack([price_df["WMB"], price_df["MPLX"]]))
X4 = StandardScaler().fit_transform(np.column_stack([price_df["KMI"], price_df["MPLX"]]))
X5 = StandardScaler().fit_transform(np.column_stack([price_df["MPC"], price_df["VLO"]]))
# Out:
# X1_raw.head:
#  [[33.13132477 16.13158989]
#  [33.86820221 16.33063507]
#  [33.41114807 16.2401638 ]
#  [33.15930557 16.3034935 ]
#  [33.25258636 16.38492012]]
# X1.head:
#  [[-1.62577172 -1.56131105]
#  [-1.55151351 -1.51625316]
#  [-1.59757276 -1.53673316]
#  [-1.62295197 -1.5223972 ]
#  [-1.61355168 -1.50396465]]

# %% [markdown]
# ### Filtration Functions
# We can choose from a large selection of possible filtration functions to use in this experiment. The choices are extremely vast, but to stay on the topic of correlation, we might want to start with a function $f$ that measures the distance between $x, y$ for $(x,y) \in \mathbb{R}^2$. So, we will use the following function for the experiment:
#
# $$
# f: X \subset \mathbb{R}^2 \to \mathbb{R}, \text{ } f(x, y) =  |x - y|.
# $$

# %%
def f(X: np.ndarray) -> np.ndarray:
    X = np.asarray(X, dtype=np.float64)
    return np.abs(X[..., 0] - X[..., 1])

# example output of f(X1)
print("First few differences of X1:")
print(f(X1)[:5])
# Out:
# First few differences of X1:
# [0.06446067 0.03526035 0.0608396  0.10055477 0.10958703]

# %% [markdown]
# Alternatively, we could have chosen functions like softmax, 2-norm, max, min, etc., but we will stick with the distance function for the graph generation in this notebook.
#
# ### Graph Construction: High Correlation
# Using libraries like **kmapper** and **sklearn**, we can ease the graph generation process and construct interactive graphs in HTML format. Let us start with our first data set, $X_1$, which we already normalized. First, we can initialize our Mapper object from the **kmapper** library and apply our lens (filter) function to our data:

# %%
import kmapper as km

# Initialize KeplerMapper and compute filtration function
mapper = km.KeplerMapper(verbose=1)
lens = f(X1)

# %% [markdown]
# And now we can define our parameters for our covers, which are closed intervals when we consider $\mathbb{R}^1$. With $N$ covers and and overlap percentage $\alpha$, we construct our covers of $f(X_1)$:
#
# *Recall we wish to construct intervals $I_i$ such that all of $ \text{Im}f$ is covered, i.e.:* $[\min f(X), \max f(X)] = \bigcup_i I_i.$
#
#
# We define the width of each interval $I_i$:
#
# $$
# w = \frac{\max f(X) - \min f(X)}{N- \alpha (N-1)},
# $$
#
# and our step magnitude as $s = w(1-\alpha)$. Iteratively, we build covers $I_1, I_2, ..., I_N$:
#
# $$
# I_j = [\min f(X) + (j-1)s, (\min f(X) + (j-1)s)+w]
# $$
#
# The following code will both set our cover parameters and **DBSCAN** clustering parameters.

# %%
from sklearn.cluster import DBSCAN

# Build 6 intervals with 30% overlap
cover = km.Cover(n_cubes=6, perc_overlap=0.3)

# Set DBSCAN clustering params for kmapper
clusterer = DBSCAN(eps=0.5, min_samples=3)

# %% [markdown]
# In **learning.ipynb**, you can see visuals of all steps up to the graph. In this notebook, we focus more on the resulting graphs rather than intermediate processes. Let us construct the final graph for data $X_1$:

# %%
# Build graph
graph = mapper.map(
    lens,
    X1,
    cover=cover,
    clusterer=clusterer
)

color_values = lens
mapper.visualize(graph, path_html="WMB_KMI_price_map.html", title="Mapper Graph: WMB-KMI Price (distance filter)", color_values=color_values, color_function_name="Absolute Difference")

# %% [markdown]
# This graph is in located in **output\8_Nodes_DBSCAN_3\WMBI_KMI_price_map.png**. Using $6$ covers in the projection space and running DBSCAN clustering of our original points $X_1$ by respective cover group, we produce a graph with:
# * $8$ edges
# * $7$ nodes
# * All nodes are connected by edges but without loop so we have $H_0 = 1$, or in Betti notation, $\beta _0 = 1$
# * No loops/cycles so $H_1, \beta _1 = 0$
#
# Below, is the scatter plot of data set $\tilde{X_1} = (\tilde{\text{WMB}}_i, \tilde{\text{KMI}}_i)$ with our highest correlation coefficient of the five experimental data sets $\rho = 0.986$. Following this scatter plot, is the resulting Mapper graph generated using above parameters.

# %%
from IPython.display import Image, display

plt.scatter(x=X1[:, 0], y=X1[:, 1], color = "black", s=10)
plt.xlabel(r"$\tilde{WMB}$")
plt.ylabel(r"$\tilde{KMI}$")
plt.tight_layout()
plt.show()
display(Image(filename="png/6_cover/WMB_KMI graph.png"))

# %% [markdown]
# A smooth structure in our resulting graph is exactly what we would expect given our highly correlated data. With our lens function $L(x,y) = |x-y|$, and the almost perfectly linear scatter plot above, we would expect a similar linear structure in the graph (which we do have). The slight deviations in the top/bottom right of the Mapper graph indicate deviations in $L(X)$, and looking back at the scatter plot, that deviation is what we do in fact see - here, we see clusters of points that deviate from the usual lens value $L = |x-y| \approx 0$.
#
#
# We will write a function **MapGraph** that we will use to construct the Mapper graph for the remaining four bivariate data sets...

# %%
from numpy.typing import ArrayLike
from typing import Callable, Tuple, Any

def MapGraph(X: ArrayLike,
             lens: Callable[[np.ndarray], Any],
             N_covers: int,
             cover_overlap: float = 0.3,
             cluster_sampling: int = 3,
             km_verbose: int = 1,
             graph_name: str = "Graph") -> None:
    fX = np.asarray(lens(X))
    mapper = km.KeplerMapper(verbose=km_verbose)

    cover = km.Cover(
        n_cubes = N_covers,
        perc_overlap=cover_overlap
    )

    clusterer = DBSCAN(eps=0.5, min_samples=cluster_sampling)

    graph = mapper.map(
        fX,
        X,
        cover=cover,
        clusterer=clusterer
    )
    
    colors = fX
    mapper.visualize(
        graph,
        path_html = f"{graph_name}.html",
        title = f"{graph_name}.html",
        color_values = colors,
        color_function_name=f"{lens.__name__}"
    )

MapGraph(X=X2, lens=f, N_covers=6, cover_overlap=0.3, cluster_sampling=3, graph_name="EPD_MPLX_price_map")
MapGraph(X=X3, lens=f, N_covers=6, cover_overlap=0.3, cluster_sampling=3, graph_name="WMB_MPLX_price_map")
MapGraph(X=X4, lens=f, N_covers=6, cover_overlap=0.3, cluster_sampling=3, graph_name="KMI_MPLX_price_map")
MapGraph(X=X5, lens=f, N_covers=6, cover_overlap=0.3, cluster_sampling=3, graph_name="MPC_VLO_price_map")

# %% [markdown]
# The resulting graphs are found in **/png/6_cover/**. However, we can draw the following observations of our correlated bivariate data sets:
#
# 1. The average correlation of data sets $X_1, ..., X_5$ was $\rho = 0.9628$
# 2. The average node count for these graphs was approximately $12$
# 3. The linearity of our graphs decreased as correlation $\rho$ decreased
# 4. The graphs had roughly $2-3$ majority nodes
# 5. $H_0 \leq 2$ for all graphs
#
# We record the observed data correlation to number of graph nodes relationship for our experiment below:
#
# *A test using larger sets of random data will be used later in the notebook to capture this relationship more accurately.*

# %%
correlations_in_order = [0.986, 0.975, 0.96, 0.951, 0.942]
n_nodes_respective = [8, 11, 15, 14, 13]

plt.plot(correlations_in_order, n_nodes_respective, color="blue")
plt.xlabel("Correlation Coefficient of Data")
plt.ylabel("Number of Graph Nodes")
plt.ylim(0)
plt.show()

# %% [markdown]
# ### Graph Construction: Low Correlation
#
# Repeating the same process in the previous section, we will generate bivariate data sets with low correlation ($|\rho| < 0.5$), normalize our data, and feed it into our function **MapGraph** under the same parameters, and observe resulting graphs.

# %%
# Build bivariate asset data

primary = ["XOM", "CVX", "COP", "EOG", "MPC","VLO", "SLB", "HAL", "BKR", "OXY"]
secondary = ["CMG", "NVDA", "AMD", "NFLX", "META","COST", "MCD", "NKE", "SBUX", "ADBE"]
prices = []
for eq in primary:
    data = yf.Ticker(eq).history(start="2024-01-01", end="2025-11-22", interval='1d')["Close"]
    prices.append(data.rename(eq))
for eq in secondary:
    data = yf.Ticker(eq).history(start="2024-01-01", end="2025-11-22", interval='1d')["Close"]
    prices.append(data.rename(eq))

price_df = pd.concat(prices, axis=1)
corr_matrix = price_df.corr()
threshold = 0.5
# upper-triangle mask (excluding diagonal)
mask = np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)

# apply mask and threshold
rows, cols = np.where((abs(corr_matrix.values) < threshold) & mask)

for i, j in zip(rows, cols):
    print(f"({corr_matrix.index[i]}, {corr_matrix.columns[j]}): {corr_matrix.iat[i, j]:.3f}")
# Out:
# (XOM, COP): 0.135
# (XOM, MPC): 0.440
# (XOM, SLB): -0.096
# (XOM, HAL): -0.013
# (XOM, BKR): 0.457
# (XOM, OXY): -0.012
# (XOM, CMG): -0.005
# (XOM, AMD): 0.228
# (XOM, NFLX): 0.212
# (XOM, META): 0.328
# (XOM, COST): 0.250
# (XOM, MCD): 0.038
# (XOM, NKE): -0.314
# (XOM, SBUX): -0.017
# (XOM, ADBE): -0.311
# (CVX, COP): 0.094
# (CVX, EOG): 0.436
# (CVX, MPC): 0.406
# (CVX, SLB): -0.037
# (CVX, HAL): 0.007
# (CVX, OXY): 0.011
# (CVX, CMG): -0.179
# (CVX, NVDA): 0.486
# (CVX, AMD): 0.265
# (CVX, NFLX): 0.303
# (CVX, META): 0.440
# (CVX, COST): 0.165
# (CVX, MCD): 0.058
# (CVX, NKE): -0.076
# (CVX, SBUX): 0.112
# (CVX, ADBE): -0.399
# (COP, MPC): 0.316
# (COP, VLO): 0.270
# (COP, AMD): 0.149
# (COP, SBUX): -0.191
# (EOG, MPC): 0.001
# (EOG, VLO): 0.063
# (EOG, SLB): 0.310
# (EOG, HAL): 0.248
# (EOG, BKR): 0.132
# (EOG, OXY): 0.363
# (EOG, NVDA): -0.006
# (EOG, AMD): -0.308
# (EOG, NFLX): -0.142
# (EOG, META): 0.061
# (EOG, COST): 0.092
# (EOG, MCD): -0.277
# (EOG, NKE): 0.055
# (EOG, SBUX): 0.297
# (EOG, ADBE): 0.150
# (MPC, SLB): 0.198
# (MPC, HAL): 0.326
# (MPC, BKR): 0.051
# (MPC, OXY): 0.324
# (MPC, CMG): -0.261
# (MPC, NVDA): 0.251
# (MPC, NFLX): 0.034
# (MPC, META): 0.118
# (MPC, COST): -0.312
# (MPC, MCD): -0.218
# (MPC, NKE): 0.227
# (MPC, SBUX): -0.333
# (MPC, ADBE): -0.110
# (VLO, SLB): 0.171
# (VLO, HAL): 0.319
# (VLO, BKR): 0.215
# (VLO, OXY): 0.283
# (VLO, CMG): -0.282
# (VLO, NVDA): 0.346
# (VLO, NFLX): 0.059
# (VLO, META): 0.153
# (VLO, COST): -0.234
# (VLO, MCD): -0.239
# (VLO, NKE): 0.130
# (VLO, SBUX): -0.342
# (VLO, ADBE): -0.184
# (SLB, CMG): 0.465
# (SLB, AMD): 0.158
# (SLB, SBUX): -0.110
# (HAL, CMG): 0.449
# (HAL, AMD): 0.327
# (HAL, SBUX): -0.264
# (BKR, AMD): 0.031
# (BKR, SBUX): 0.350
# (OXY, AMD): 0.189
# (OXY, SBUX): -0.307
# (CMG, NVDA): -0.447
# (CMG, AMD): -0.374
# (CMG, META): -0.392
# (CMG, COST): -0.166
# (CMG, NKE): 0.346
# (CMG, SBUX): 0.045
# (NVDA, AMD): 0.288
# (NVDA, MCD): 0.469
# (NVDA, SBUX): 0.087
# (AMD, NFLX): -0.076
# (AMD, META): 0.012
# (AMD, COST): -0.369
# (AMD, MCD): -0.143
# (AMD, NKE): 0.302
# (AMD, SBUX): -0.300
# (AMD, ADBE): 0.010
# (NFLX, SBUX): 0.212
# (META, SBUX): 0.346
# (COST, SBUX): 0.385
# (MCD, SBUX): 0.471
# (NKE, SBUX): -0.012
# (SBUX, ADBE): -0.011

# %%
from sklearn.preprocessing import StandardScaler

# Generate bivariate data sets
Y1 = StandardScaler().fit_transform(np.column_stack([price_df["XOM"], price_df["MPC"]]))     #p = 0.440
Y2 = StandardScaler().fit_transform(np.column_stack([price_df["XOM"], price_df["AMD"]]))     #p = 0.228
Y3 = StandardScaler().fit_transform(np.column_stack([price_df["COST"], price_df["SBUX"]]))   #p = 0.385
Y4 = StandardScaler().fit_transform(np.column_stack([price_df["CVX"], price_df["OXY"]]))     #p = 0.011
Y5 = StandardScaler().fit_transform(np.column_stack([price_df["CVX"], price_df["NVDA"]]))    #p = 0.486

# Build graphs using same lens function and clustering parameters
MapGraph(X=Y1, lens=f, N_covers=6, cover_overlap=0.3, cluster_sampling=3, graph_name="XOM_MPC_price_map")
MapGraph(X=Y2, lens=f, N_covers=6, cover_overlap=0.3, cluster_sampling=3, graph_name="XOM_AMD_price_map")
MapGraph(X=Y3, lens=f, N_covers=6, cover_overlap=0.3, cluster_sampling=3, graph_name="COST_SBUX_price_map")
MapGraph(X=Y4, lens=f, N_covers=6, cover_overlap=0.3, cluster_sampling=3, graph_name="CVX_OXY_price_map")
MapGraph(X=Y5, lens=f, N_covers=6, cover_overlap=0.3, cluster_sampling=3, graph_name="CVX_NVDA_price_map")

# %% [markdown]
# The following is a scatter and respective graph for data set $Y_2$, which had a recorded correlation of $\rho = 0.228$:

# %%
plt.scatter(x=Y2[:, 0], y=Y2[:, 1], color = "black", s=10)
plt.xlabel(r"$\tilde{XOM}$")
plt.ylabel(r"$\tilde{AMD}$")
plt.tight_layout()
plt.show()
display(Image(filename="png/6_cover/XOM_AMD graph.png"))

# %% [markdown]
# Given the graphs generated by our data sets $Y_1, ..., Y_5$, we make the following observations:
#
# 1. The average data set correlation was $\rho=0.31$
# 2. The average number of nodes for a graph was roughly $17$
# 3. Graphs did not have much linear structure
# 4. The bound for $H_0$ increased to $H_0 \leq 3$ for all graphs
# 5. We observed our first instance of a nontrivial $1$-dimension cycle; data set $Y_2$ yielded $H_1=1>0$ in its graph
